# %%
#André Coelho Solér - RM 98827
#Gabriel Ferla - RM550695

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
text_file = pd.read_csv('/content/top50.csv', encoding='latin-1')

# %%
df = text_file

# %%
df
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
#Qual é a distribuição dos gêneros musicais nas músicas fornecidas?
genero_distribuicao = df['Genre'].value_counts()
plt.figure(figsize=(10, 6))
genero_distribuicao.plot(kind='bar')
plt.title('Distribuição dos Gêneros Musicais')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Relação entre dançabilidade e energia das músicas (gráfico de dispersão)
plt.figure(figsize=(8, 6))
plt.scatter(df['Danceability'], df['Energy'], color='green', alpha=0.5)
plt.title('Relação entre Dançabilidade e Energia das Músicas')
plt.xlabel('Dançabilidade')
plt.ylabel('Energia')
plt.show()

# %%
# 3. Distribuição da popularidade das músicas (gráfico de colunas)
popularity_mean = df.groupby('Artist.Name')['Popularity'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
popularity_mean.plot(kind='bar')
plt.title('Top 10 Artistas com Maior Popularidade Média')
plt.xlabel('Artista')
plt.ylabel('Popularidade Média')
plt.xticks(rotation=45)
plt.show()

# %%
# 4. Relação entre dançabilidade e energia das músicas (gráfico de dispersão)

plt.figure(figsize=(8, 6))
plt.scatter(df['Danceability'], df['Energy'], color='green', alpha=0.5)
plt.title('Relação entre Dançabilidade e Energia das Músicas')
plt.xlabel('Dançabilidade')
plt.ylabel('Energia')
plt.show()

# %%
# 5. Distribuição do volume (loudness) das músicas (indicador)
plt.figure(figsize=(8, 6))
plt.hist(df['Popularity'], bins=20, color='orange')
plt.title('Distribuição da Popularidade das Músicas')
plt.xlabel('Popularidade')
plt.ylabel('Contagem')
plt.show()

# %%
# 6. Relação entre duração das músicas e popularidade (gráfico de dispersão)
plt.figure(figsize=(8, 6))
plt.scatter(df['Length.'], df['Popularity'], color='purple', alpha=0.5)
plt.title('Relação entre Duração das Músicas e Popularidade')
plt.xlabel('Duração (segundos)')
plt.ylabel('Popularidade')
plt.show()

# %%
# 7. Distribuição do volume (loudness) das músicas (histograma)
plt.figure(figsize=(8, 6))
plt.hist(df['Loudness..dB..'], bins=20, color='pink')
plt.title('Distribuição do Volume (Loudness) das Músicas')
plt.xlabel('Volume (Loudness)')
plt.ylabel('Contagem')
plt.show()
